# %%
import pandas as pd

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %% [markdown]
# ## The pd.concat() Method, Part 1

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
len(pd.concat([week1, week2]))
# Out:
# 500

# %%
pd.concat([week1, week2], ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# 473          540        3
# 474          735        2
# 475          940        8
# 476          571        7
# 477          888        2
# 478          664        6
# 479          343        7
# 480          143        4
# 481          505        3
# 482           54        8
# 483          959        2
# 484          367        8
# 485          883        8
# 486          251        9
# 487          855        4
# 488          233        3
# 489          559       10
# 490          734        1
# 491          677        3
# 492          276        4
# 493           45        8
# 494          945        4
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1, week2, customers], ignore_index=True)
# Out:
#            Company  Customer ID First Name  Food ID  Gender      ID Last Name  \
# 0              NaN        537.0        NaN      9.0     NaN     NaN       NaN
# 1              NaN         97.0        NaN      4.0     NaN     NaN       NaN
# 2              NaN        658.0        NaN      1.0     NaN     NaN       NaN
# 3              NaN        202.0        NaN      2.0     NaN     NaN       NaN
# 4              NaN        155.0        NaN      9.0     NaN     NaN       NaN
# 5              NaN        213.0        NaN      8.0     NaN     NaN       NaN
# 6              NaN        600.0        NaN      1.0     NaN     NaN       NaN
# 7              NaN        503.0        NaN      5.0     NaN     NaN       NaN
# 8              NaN         71.0        NaN      3.0     NaN     NaN       NaN
# 9              NaN        174.0        NaN      3.0     NaN     NaN       NaN
# 10             NaN        961.0        NaN      9.0     NaN     NaN       NaN
# 11             NaN        966.0        NaN      5.0     NaN     NaN       NaN
# 12             NaN        641.0        NaN      4.0     NaN     NaN       NaN
# 13             NaN        288.0        NaN      2.0     NaN     NaN       NaN
# 14             NaN        149.0        NaN      4.0     NaN     NaN       NaN
# 15             NaN        954.0        NaN      2.0     NaN     NaN       NaN
# 16             NaN        147.0        NaN      9.0     NaN     NaN       NaN
# 17             NaN        155.0        NaN      1.0     NaN     NaN       NaN
# 18             NaN        550.0        NaN      6.0     NaN     NaN       NaN
# 19             NaN        101.0        NaN      7.0     NaN     NaN       NaN
# 20             NaN        549.0        NaN      6.0     NaN     NaN       NaN
# 21             NaN         75.0        NaN      6.0     NaN     NaN       NaN
# 22             NaN         78.0        NaN      7.0     NaN     NaN       NaN
# 23             NaN        514.0        NaN      5.0     NaN     NaN       NaN
# 24             NaN        833.0        NaN      7.0     NaN     NaN       NaN
# 25             NaN        329.0        NaN      8.0     NaN     NaN       NaN
# 26             NaN        586.0        NaN     10.0     NaN     NaN       NaN
# 27             NaN        341.0        NaN      1.0     NaN     NaN       NaN
# 28             NaN        519.0        NaN     10.0     NaN     NaN       NaN
# 29             NaN        680.0        NaN      9.0     NaN     NaN       NaN
# ...            ...          ...        ...      ...     ...     ...       ...
# 1470      Riffwire          NaN    Melissa      NaN  Female   971.0    Wagner
# 1471    Topicstorm          NaN     Rachel      NaN  Female   972.0    Snyder
# 1472      Centidel          NaN     Sandra      NaN  Female   973.0    Graham
# 1473      Realcube          NaN      Chris      NaN    Male   974.0     Gomez
# 1474       Dabtype          NaN      Laura      NaN  Female   975.0  Stephens
# 1475         Avamm          NaN      Emily      NaN  Female   976.0      Cole
# 1476       Skalith          NaN    Cynthia      NaN  Female   977.0     Dixon
# 1477        Meedoo          NaN     Gerald      NaN    Male   978.0   Sanders
# 1478      Jaxworks          NaN       Ruth      NaN  Female   979.0      Ward
# 1479        Camido          NaN     Jeremy      NaN    Male   980.0  Anderson
# 1480         Lazzy          NaN    Raymond      NaN    Male   981.0  Morrison
# 1481      Feedfire          NaN  Christine      NaN  Female   982.0    Holmes
# 1482          DabZ          NaN     Angela      NaN  Female   983.0    Fisher
# 1483       Gabspot          NaN      Randy      NaN    Male   984.0     Green
# 1484        Kwideo          NaN      Julia      NaN  Female   985.0     Ortiz
# 1485       Gabtype          NaN     Harold      NaN    Male   986.0    Parker
# 1486      Digitube          NaN     Joshua      NaN    Male   987.0    Howell
# 1487          Eayo          NaN       Todd      NaN    Male   988.0     Perry
# 1488       Youopia          NaN      Jimmy      NaN    Male   989.0     James
# 1489        Oyondu          NaN      Jesse      NaN    Male   990.0    Wagner
# 1490         Lazzy          NaN    Melissa      NaN  Female   991.0     Wells
# 1491      Fanoodle          NaN     Andrea      NaN  Female   992.0    Howard
# 1492      Feedfish          NaN     Edward      NaN    Male   993.0     Mills
# 1493      Edgewire          NaN   Clarence      NaN    Male   994.0    Morgan
# 1494        Trilia          NaN      Sarah      NaN  Female   995.0    Nguyen
# 1495  Dazzlesphere          NaN      Debra      NaN  Female   996.0    Garcia
# 1496      Livepath          NaN    Douglas      NaN    Male   997.0    Bishop
# 1497    Brainverse          NaN      Frank      NaN    Male   998.0  Franklin
# 1498    Babbleblab          NaN    Jessica      NaN  Female   999.0     Burns
# 1499         Tazzy          NaN      Brian      NaN    Male  1000.0   Daniels
#
#                           Occupation
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               NaN
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
# ...                              ...
# 1470                  Civil Engineer
# 1471  Payment Adjustment Coordinator
# 1472             Software Consultant
# 1473    Structural Analysis Engineer
# 1474                Graphic Designer
# 1475           Chief Design Engineer
# 1476        Automation Specialist II
# 1477              VP Quality Control
# 1478               Account Executive
# 1479                       Recruiter
# 1480               Account Executive
# 1481                Media Manager IV
# 1482            Help Desk Technician
# 1483          Nuclear Power Engineer
# 1484    Structural Analysis Engineer
# 1485             Account Coordinator
# 1486             Office Assistant IV
# 1487                 Data Coordiator
# 1488      Database Administrator III
# 1489         Human Resources Manager
# 1490          Senior Sales Associate
# 1491                 Data Coordiator
# 1492                Health Coach III
# 1493                    Geologist II
# 1494                   Programmer IV
# 1495             Structural Engineer
# 1496                     Developer I
# 1497              Nurse Practicioner
# 1498               Financial Advisor
# 1499      Physical Therapy Assistant
#
# [1500 rows x 8 columns]

# %% [markdown]
# ## The pd.concat() Method, Part 2

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
sales = pd.concat([week1, week2], keys=["A", "B"])

# %%
sales.ix[("B", 240), "Customer ID"]
# Out:
# 734

# %% [markdown]
# ## The .append() Method

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
sales = week2.append(week1, ignore_index=True)

# %% [markdown]
# ## Inner Joins, Part 1

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how="inner", on="Customer ID", suffixes=[" - Week 1", " - Week 2"])
# Out:
#     Customer ID  Food ID - Week 1  Food ID - Week 2
# 0           537                 9                 5
# 1           155                 9                 3
# 2           155                 1                 3
# 3           503                 5                 8
# 4           503                 5                 9
# 5           550                 6                 7
# 6           101                 7                 4
# 7            75                 6                 4
# 8            77                 1                 7
# 9            77                 9                 7
# 10           77                 2                 7
# 11           77                 9                 7
# 12          628                 4                 7
# 13          798                 9                 5
# 14          798                 1                 5
# 15          462                 3                 8
# 16          304                 3                 3
# 17          304                 2                 3
# 18          189                 4                 5
# 19          799                 8                 7
# 20           30                 2                 4
# 21          249                 9                 6
# 22          677                10                 3
# 23          741                 3                 8
# 24          540                 3                 3
# 25          819                 4                 5
# 26          937                10                10
# 27          937                10                 2
# 28          233                 3                 3
# 29           21                 4                 4
# ..          ...               ...               ...
# 32          816                 7                 2
# 33          761                 9                 2
# 34          761                 9                 3
# 35           80                 2                 4
# 36          479                 6                 3
# 37          922                 1                 1
# 38          922                 1                 2
# 39          909                 1                 6
# 40          909                 4                 6
# 41          919                10                 8
# 42          574                10                 9
# 43           45                 7                 8
# 44          529                 7                10
# 45          673                 7                 4
# 46          310                 2                 5
# 47          310                 1                 5
# 48          867                 9                10
# 49          968                 1                 4
# 50          482                 3                 1
# 51          163                 1                10
# 52          321                 1                 3
# 53          783                 6                10
# 54          578                 5                 5
# 55          578                 5                 5
# 56          520                 8                 7
# 57          945                 5                 4
# 58          343                 3                 5
# 59          343                 3                 2
# 60          343                 3                 7
# 61          621                 9                 6
#
# [62 rows x 3 columns]

# %%
week1[week1["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %% [markdown]
# ## 121 - Inner Joins, Part 2

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how='inner', on=['Customer ID', 'Food ID'])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1['Customer ID'] == 578]
# Out:
#      Customer ID  Food ID
# 224          578        5

# %%
week2[week2['Customer ID'] == 578]
# Out:
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %% [markdown]
# ## 122 - Outer Joins

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
merged = week1.merge(week2, how='outer', on='Customer ID', suffixes=[' - Week 1', ' - Week2'], 
            indicator=True)

# %%
merged['_merge'].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
mask = merged['_merge'].isin(['left_only', 'right_only'])
merged[mask]
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week2      _merge
# 1             97               4.0              NaN   left_only
# 2            658               1.0              NaN   left_only
# 3            202               2.0              NaN   left_only
# 6            213               8.0              NaN   left_only
# 7            600               1.0              NaN   left_only
# 10            71               3.0              NaN   left_only
# 11            71               8.0              NaN   left_only
# 12           174               3.0              NaN   left_only
# 13           961               9.0              NaN   left_only
# 14           966               5.0              NaN   left_only
# 15           641               4.0              NaN   left_only
# 16           288               2.0              NaN   left_only
# 17           149               4.0              NaN   left_only
# 18           954               2.0              NaN   left_only
# 19           147               9.0              NaN   left_only
# 20           147               8.0              NaN   left_only
# 23           549               6.0              NaN   left_only
# 25            78               7.0              NaN   left_only
# 26           514               5.0              NaN   left_only
# 27           833               7.0              NaN   left_only
# 28           833               3.0              NaN   left_only
# 29           329               8.0              NaN   left_only
# 30           586              10.0              NaN   left_only
# 31           341               1.0              NaN   left_only
# 32           519              10.0              NaN   left_only
# 33           680               9.0              NaN   left_only
# 34           419               7.0              NaN   left_only
# 35            20               1.0              NaN   left_only
# 36           822               6.0              NaN   left_only
# 37           226              10.0              NaN   left_only
# ..           ...               ...              ...         ...
# 424          622               NaN              9.0  right_only
# 425          959               NaN              4.0  right_only
# 426          959               NaN              2.0  right_only
# 427          810               NaN              2.0  right_only
# 428          488               NaN              2.0  right_only
# 429          188               NaN              8.0  right_only
# 430          305               NaN              2.0  right_only
# 431          869               NaN              7.0  right_only
# 432          131               NaN              1.0  right_only
# 433          208               NaN              4.0  right_only
# 434          145               NaN              5.0  right_only
# 435          794               NaN              6.0  right_only
# 436          734               NaN             10.0  right_only
# 437          734               NaN              1.0  right_only
# 438          735               NaN              2.0  right_only
# 439          940               NaN              8.0  right_only
# 440          571               NaN              7.0  right_only
# 441          888               NaN              2.0  right_only
# 442          664               NaN              6.0  right_only
# 443          143               NaN              4.0  right_only
# 444          505               NaN              3.0  right_only
# 445           54               NaN              8.0  right_only
# 446          367               NaN              8.0  right_only
# 447          883               NaN              8.0  right_only
# 448          251               NaN              9.0  right_only
# 449          855               NaN              4.0  right_only
# 450          559               NaN             10.0  right_only
# 451          276               NaN              4.0  right_only
# 452          556               NaN             10.0  right_only
# 453          252               NaN              9.0  right_only
#
# [392 rows x 4 columns]

# %% [markdown]
# ## 123 - Left Joins

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1 = week1.merge(foods, how='left', on='Food ID', sort=True)

# %%
week1.head()
# Out:
#    Customer ID  Food ID Food Item  Price
# 0          658        1     Sushi   3.99
# 1          600        1     Sushi   3.99
# 2          155        1     Sushi   3.99
# 3          341        1     Sushi   3.99
# 4           20        1     Sushi   3.99

# %% [markdown]
# ## 09.124 - The left_on and right_on Parameters

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
week2 = week2.merge(customers, how='left', left_on = 'Customer ID', right_on = 'ID', sort = True).drop('ID', axis='columns')

# %%
week2.head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender        Company  \
# 0            8        6    Frances     Adams  Female       Dabshots
# 1           13        2       Ruth   Alvarez  Female    Twitterlist
# 2           21        4     Albert     Burns    Male      Rhynoodle
# 3           24        8      Donna    Thomas  Female        Jaxbean
# 4           27        4    Jessica   Bennett  Female  Twitternation
#
#                     Occupation
# 0                Developer III
# 1  Mechanical Systems Engineer
# 2             Junior Executive
# 3        Chief Design Engineer
# 4            Account Executive

# %% [markdown]
# ## 09.125 Merging by Indexes with the left_index and right_index Parameters

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv", index_col="ID")
foods = pd.read_csv("Restaurant - Foods.csv", index_col="Food ID")

# %%
foods.head(3)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99
# 3            Taco   2.99

# %%
sales = week1.merge(customers, how="left", left_on="Customer ID", right_index=True)
sales = sales.merge(foods, how="left", left_on="Food ID", right_index=True)
sales.head(3)
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
#
#                       Occupation   Food Item  Price
# 0               Registered Nurse       Donut   0.99
# 1            Account Coordinator  Quesadilla   4.25
# 2  Community Outreach Specialist       Sushi   3.99

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
week1.merge(week2, how="left", left_index=True, right_index=True, suffixes = [" - Week 1", " - Week 2"])
# Out:
#      Customer ID - Week 1  Food ID - Week 1  Customer ID - Week 2  \
# 0                     537                 9                   688
# 1                      97                 4                   813
# 2                     658                 1                   495
# 3                     202                 2                   189
# 4                     155                 9                   267
# 5                     213                 8                   310
# 6                     600                 1                   761
# 7                     503                 5                   443
# 8                      71                 3                   729
# 9                     174                 3                   741
# 10                    961                 9                   847
# 11                    966                 5                   156
# 12                    641                 4                   550
# 13                    288                 2                   620
# 14                    149                 4                   272
# 15                    954                 2                   511
# 16                    147                 9                     8
# 17                    155                 1                   534
# 18                    550                 6                   909
# 19                    101                 7                   732
# 20                    549                 6                   372
# 21                     75                 6                   713
# 22                     78                 7                   496
# 23                    514                 5                   381
# 24                    833                 7                    13
# 25                    329                 8                   101
# 26                    586                10                   325
# 27                    341                 1                   674
# 28                    519                10                   564
# 29                    680                 9                   578
# ..                    ...               ...                   ...
# 220                   147                 8                   495
# 221                   745                 4                   794
# 222                   184                 3                   734
# 223                   828                 8                   540
# 224                   578                 5                   735
# 225                   491                 4                   940
# 226                    62                 4                   571
# 227                    77                 9                   888
# 228                   506                 9                   664
# 229                   271                 9                   343
# 230                   584                10                   143
# 231                   148                 5                   505
# 232                   595                 3                    54
# 233                   274                10                   959
# 234                   646                 1                   367
# 235                   520                 8                   883
# 236                   644                 8                   251
# 237                   725                 8                   855
# 238                   934                 4                   233
# 239                   151                10                   559
# 240                   945                 5                   734
# 241                   343                 3                   677
# 242                   380                 9                   276
# 243                   911                 4                    45
# 244                   621                 9                   945
# 245                   413                 9                   783
# 246                   926                 6                   556
# 247                   134                 3                   547
# 248                   396                 6                   252
# 249                   535                10                   249
#
#      Food ID - Week 2
# 0                  10
# 1                   7
# 2                  10
# 3                   5
# 4                   3
# 5                   5
# 6                   2
# 7                   5
# 8                   9
# 9                   8
# 10                  6
# 11                 10
# 12                  7
# 13                 10
# 14                  4
# 15                  2
# 16                  6
# 17                  7
# 18                  6
# 19                  9
# 20                  4
# 21                  1
# 22                  3
# 23                  9
# 24                  2
# 25                  4
# 26                  7
# 27                  2
# 28                  8
# 29                  5
# ..                ...
# 220                 2
# 221                 6
# 222                10
# 223                 3
# 224                 2
# 225                 8
# 226                 7
# 227                 2
# 228                 6
# 229                 7
# 230                 4
# 231                 3
# 232                 8
# 233                 2
# 234                 8
# 235                 8
# 236                 9
# 237                 4
# 238                 3
# 239                10
# 240                 1
# 241                 3
# 242                 4
# 243                 8
# 244                 4
# 245                10
# 246                10
# 247                 9
# 248                 9
# 249                 6
#
# [250 rows x 4 columns]

# %% [markdown]
# ## 09.126 The .join() Method

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")
satisfaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
satisfaction.head()
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3
# 3                    7
# 4                   10

# %%
week1.merge(satisfaction, how="left", left_index = True, right_index=True).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
week1.join(satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %% [markdown]
# ## 09.127 The pd.merge() Method

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")
satisfaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
pd.merge(week1, customers, how="left", left_on="Customer ID", right_on="ID")
# Out:
#      Customer ID  Food ID   ID First Name  Last Name  Gender       Company  \
# 0            537        9  537     Cheryl    Carroll  Female      Zoombeat
# 1             97        4   97     Amanda    Watkins  Female           Ozu
# 2            658        1  658    Patrick       Webb    Male     Browsebug
# 3            202        2  202      Louis   Campbell    Male     Rhynoodle
# 4            155        9  155    Carolyn       Diaz  Female      Gigazoom
# 5            213        8  213      Keith     Foster    Male     Gigashots
# 6            600        1  600     Sandra     Bailey  Female     Jaxnation
# 7            503        5  503     Justin    Daniels    Male          Oloo
# 8             71        3   71    Carolyn      Reyes  Female        Twimbo
# 9            174        3  174       Anna     Miller  Female       Innojam
# 10           961        9  961      Ralph   Richards    Male  Thoughtstorm
# 11           966        5  966     Robert       Ford    Male    Jabbertype
# 12           641        4  641      Donna  Gutierrez  Female       Dabtype
# 13           288        2  288    Kenneth    Jackson    Male         Voomm
# 14           149        4  149   Jennifer     Oliver  Female   Topiclounge
# 15           954        2  954     Thomas    Perkins    Male        Roodel
# 16           147        9  147    Theresa    Morales  Female         Abata
# 17           155        1  155    Carolyn       Diaz  Female      Gigazoom
# 18           550        6  550     Walter     Miller    Male          Yata
# 19           101        7  101     Jeremy     Nelson    Male   Brainlounge
# 20           549        6  549     Harold     Rivera    Male      Topdrive
# 21            75        6   75  Catherine  Carpenter  Female        Zoozzy
# 22            78        7   78     Robert    Kennedy    Male      Edgewire
# 23           514        5  514       Jack       Hill    Male      Blogtags
# 24           833        7  833    Carolyn       Dunn  Female         Yadel
# 25           329        8  329     Amanda     Nguyen  Female        Meezzy
# 26           586       10  586      Doris   Mcdonald  Female       Youfeed
# 27           341        1  341     Rachel   Robinson  Female       Twinder
# 28           519       10  519    Lillian     Rogers  Female         Eazzy
# 29           680        9  680      Irene     Gordon  Female       Voolith
# ..           ...      ...  ...        ...        ...     ...           ...
# 220          147        8  147    Theresa    Morales  Female         Abata
# 221          745        4  745     Nicole      Garza  Female     Topiczoom
# 222          184        3  184      Jesse    Edwards    Male      Zoombeat
# 223          828        8  828       Mary      Payne  Female       Oyonder
# 224          578        5  578     Donald   Matthews    Male      Fiveclub
# 225          491        4  491       Anna    Perkins  Female         Zazio
# 226           62        4   62     Andrew     Tucker    Male        Leenti
# 227           77        9   77       Lori    Edwards  Female       Dabvine
# 228          506        9  506    Mildred    Mendoza  Female          Vitz
# 229          271        9  271    Beverly       Ward  Female      Brainbox
# 230          584       10  584    Jeffrey    Simmons    Male     Flipstorm
# 231          148        5  148   Patricia       Reid  Female  Shuffledrive
# 232          595        3  595      Bruce    Kennedy    Male          Mydo
# 233          274       10  274       Gary       Reid    Male      Fivespan
# 234          646        1  646      Wanda       Lane  Female         Twiyo
# 235          520        8  520    Melissa    Wallace  Female         Skyvu
# 236          644        8  644      Louis     Brooks    Male       Nlounge
# 237          725        8  725      Carol    Russell  Female        BlogXS
# 238          934        4  934     Joseph     Burton    Male         Leexo
# 239          151       10  151    Brandon     Oliver    Male         Voomm
# 240          945        5  945       Anne       Reed  Female  Twitterworks
# 241          343        3  343        Joe      Price    Male      Fanoodle
# 242          380        9  380     Martha      Payne  Female         Quinu
# 243          911        4  911    Patrick       Reed    Male   Jabberstorm
# 244          621        9  621        Amy       Long  Female        Skidoo
# 245          413        9  413      Diane     Bailey  Female       Wikibox
# 246          926        6  926       Anne     Wagner  Female         Skyba
# 247          134        3  134      Diana       Hall  Female         Quinu
# 248          396        6  396       Juan     Romero    Male       Zoonder
# 249          535       10  535      Nancy        Cox  Female        Trudeo
#
#                          Occupation
# 0                  Registered Nurse
# 1               Account Coordinator
# 2     Community Outreach Specialist
# 3        Account Representative III
# 4        Database Administrator III
# 5                VP Quality Control
# 6                   Sales Associate
# 7                Environmental Tech
# 8              Safety Technician IV
# 9                       Developer I
# 10                     Accountant I
# 11        Account Representative IV
# 12              Assistant Professor
# 13              Associate Professor
# 14       Database Administrator III
# 15                Account Executive
# 16           Occupational Therapist
# 17       Database Administrator III
# 18   Payment Adjustment Coordinator
# 19                 Web Developer IV
# 20                  Cost Accountant
# 21                Marketing Manager
# 22                Chemical Engineer
# 23              Assistant Professor
# 24                        Recruiter
# 25              Associate Professor
# 26              Marketing Assistant
# 27             Safety Technician IV
# 28                        Paralegal
# 29        Database Administrator II
# ..                              ...
# 220          Occupational Therapist
# 221                 General Manager
# 222          Administrative Officer
# 223         Assistant Media Planner
# 224      Physical Therapy Assistant
# 225                Quality Engineer
# 226    Structural Analysis Engineer
# 227            Sales Representative
# 228              Environmental Tech
# 229        Automation Specialist II
# 230               Chemical Engineer
# 231   Analog Circuit Design manager
# 232                       Recruiter
# 233             Executive Secretary
# 234            Help Desk Technician
# 235          Administrative Officer
# 236              VP Quality Control
# 237                      Pharmacist
# 238            Compensation Analyst
# 239                Internal Auditor
# 240               Director of Sales
# 241               Marketing Manager
# 242         Assistant Media Planner
# 243         Senior Quality Engineer
# 244              Research Associate
# 245                Technical Writer
# 246                 Legal Assistant
# 247               Financial Advisor
# 248              Analyst Programmer
# 249              Research Associate
#
# [250 rows x 8 columns]
