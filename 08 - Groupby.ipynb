# %% [markdown]
# ## 08.109 Intro to the Groupby Module

# %%
import pandas as pd

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = "Rank")
sectors = fortune.groupby(by = "Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
type(fortune)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sectors)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
sectors

# %% [markdown]
# ## 08.110 First Operations with groupby Object

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = "Rank")
sectors = fortune.groupby(by = "Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
len(fortune)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
fortune['Sector'].nunique()
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
fortune['Sector'].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Food, Beverages & Tobacco        43
# Materials                        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Apparel                          15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
fortune.tail(3)
# Out:
#                         Company                        Sector  \
# Rank
# 997   Portland General Electric                        Energy
# 999                     Wendy’s  Hotels, Resturants & Leisure
# 1000          Briggs & Stratton                   Industrials
#
#                          Industry       Location  Revenue  Profits  Employees
# Rank
# 997   Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 999                 Food Services     Dublin, OH     1896      161      21200
# 1000         Industrial Machinery  Wauwatosa, WI     1895       46       5480

# %%
sectors.last()
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
fortune.loc[45]
# Out:
# Company        United Technologies
# Sector         Aerospace & Defense
# Industry     Aerospace and Defense
# Location            Farmington, CT
# Revenue                      61047
# Profits                       7608
# Employees                   197200
# Name: 45, dtype: object

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %% [markdown]
# ## 08.111 Retrieve A Group with the get.group() Method

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = "Rank")
sectors = fortune.groupby(by = "Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.get_group('Energy')
sectors.get_group('Technology')
sectors.get_group('Apparel')
# Out:
#                    Company   Sector Industry             Location  Revenue  \
# Rank
# 91                    Nike  Apparel  Apparel        Beaverton, OR    30601
# 231                     VF  Apparel  Apparel       Greensboro, NC    12377
# 340                    PVH  Apparel  Apparel         New York, NY     8020
# 354           Ralph Lauren  Apparel  Apparel         New York, NY     7620
# 448            Hanesbrands  Apparel  Apparel    Winston-Salem, NC     5732
# 547           Levi Strauss  Apparel  Apparel    San Francisco, CA     4495
# 575                  Coach  Apparel  Apparel         New York, NY     4192
# 597           Under Armour  Apparel  Apparel        Baltimore, MD     3963
# 683           Fossil Group  Apparel  Apparel       Richardson, TX     3229
# 695        Skechers U.S.A.  Apparel  Apparel  Manhattan Beach, CA     3159
# 726               Carter’s  Apparel  Apparel          Atlanta, GA     3014
# ...

# %%
fortune[fortune["Sector"] == 'Apparel']
# Out:
#                    Company   Sector Industry             Location  Revenue  \
# Rank
# 91                    Nike  Apparel  Apparel        Beaverton, OR    30601
# 231                     VF  Apparel  Apparel       Greensboro, NC    12377
# 340                    PVH  Apparel  Apparel         New York, NY     8020
# 354           Ralph Lauren  Apparel  Apparel         New York, NY     7620
# 448            Hanesbrands  Apparel  Apparel    Winston-Salem, NC     5732
# 547           Levi Strauss  Apparel  Apparel    San Francisco, CA     4495
# 575                  Coach  Apparel  Apparel         New York, NY     4192
# 597           Under Armour  Apparel  Apparel        Baltimore, MD     3963
# 683           Fossil Group  Apparel  Apparel       Richardson, TX     3229
# 695        Skechers U.S.A.  Apparel  Apparel  Manhattan Beach, CA     3159
# 726               Carter’s  Apparel  Apparel          Atlanta, GA     3014
# ...

# %% [markdown]
# ## 08.112 Methods on the Groupby Object and DataFrame Columns

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = "Rank")
sectors = fortune.groupby(by = "Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.get_group('Apparel')['Profits'].sum()
# Out:
# 8236

# %%
sectors.max()
sectors.min()
sectors.sum()
sectors.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
sectors.get_group('Engineering & Construction')
# Out:
#                        Company  Employees                   Industry  \
# Rank
# 155                      Fluor      38758  Engineering, Construction
# 156                      AECOM      92000  Engineering, Construction
# 235   Jacobs Engineering Group      56950  Engineering, Construction
# 260                D.R. Horton       6230               Homebuilders
# 301                     Lennar       7749               Homebuilders
# 314         Peter Kiewit Sons’      22000  Engineering, Construction
# 352            Quanta Services      24500  Engineering, Construction
# 381                EMCOR Group      29000  Engineering, Construction
# 433                 PulteGroup       4542               Homebuilders
# 478                  CH2M Hill      22000  Engineering, Construction
# 498                        NVR       4300               Homebuilders
# 501                        KBR      22000  Engineering, Construction
# ...

# %%
sectors['Revenue'].sum()
sectors['Employees'].sum()
sectors['Profits'].max()
sectors['Profits'].min()
sectors['Employees'].mean()

sectors[['Revenue', 'Profits']].sum()
# Out:
#                               Revenue  Profits
# Sector
# Aerospace & Defense            357940    28742
# Apparel                         95968     8236
# Business Services              272195    28227
# Chemicals                      243897    22628
# Energy                        1517809   -73447
# Engineering & Construction     153983     5304
# Financials                    2217159   260209
# Food and Drug Stores           483769    16759
# Food, Beverages & Tobacco      555967    51417
# Health Care                   1614707   106114
# Hotels, Resturants & Leisure   169546    20697
# Household Products             234737    14428
# Industrials                    497581    20764
# Materials                      259145     4428
# Media                          220764    24347
# Motor Vehicles & Parts         482540    25898
# Retailing                     1465076    47830
# Technology                    1377600   180473
# Telecommunications             461834    48637
# ...

# %% [markdown]
# ## 08.113 Grouping by Multiple Columns

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = "Rank")
sectors = fortune.groupby(by = ["Sector", "Industry"])
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.size()
sectors.sum()
sectors['Revenue'].sum()
sectors['Employees'].mean()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                              48402.850000
# Apparel                     Apparel                                            23093.133333
# Business Services           Advertising, marketing                             62050.000000
#                             Diversified Outsourcing Services                   50595.000000
#                             Education                                          15585.000000
#                             Financial Data Services                            13943.473684
#                             Miscellaneous                                      12573.333333
#                             Temporary Help                                     12004.000000
#                             Waste Management                                   23839.800000
# Chemicals                   Chemicals                                          15455.033333
# ...

# %% [markdown]
# ## 08.114 The .agg() Method

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = "Rank")
sectors = fortune.groupby(by = "Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.agg({'Revenue': ['sum', 'mean'],
             'Profits': 'sum',
             'Employees': 'mean'})
# Out:
#                               Revenue                   Employees Profits
#                                   sum          mean          mean     sum
# Sector
# Aerospace & Defense            357940  17897.000000  48402.850000   28742
# Apparel                         95968   6397.866667  23093.133333    8236
# Business Services              272195   5337.156863  26687.254902   28227
# Chemicals                      243897   8129.900000  15455.033333   22628
# Energy                        1517809  12441.057377   9745.303279  -73447
# Engineering & Construction     153983   5922.423077  15642.615385    5304
# Financials                    2217159  15950.784173  24172.287770  260209
# Food and Drug Stores           483769  32251.266667  93026.533333   16759
# Food, Beverages & Tobacco      555967  12929.465116  28177.488372   51417
# Health Care                   1614707  21529.426667  35710.520000  106114
# Hotels, Resturants & Leisure   169546   6781.840000  99369.800000   20697
# ...

# %%
sectors.agg(['size', 'sum', 'mean'])
# Out:
#                              Revenue                        Profits          \
#                                 size      sum          mean    size     sum
# Sector
# Aerospace & Defense               20   357940  17897.000000      20   28742
# Apparel                           15    95968   6397.866667      15    8236
# Business Services                 51   272195   5337.156863      51   28227
# Chemicals                         30   243897   8129.900000      30   22628
# Energy                           122  1517809  12441.057377     122  -73447
# Engineering & Construction        26   153983   5922.423077      26    5304
# Financials                       139  2217159  15950.784173     139  260209
# Food and Drug Stores              15   483769  32251.266667      15   16759
# Food, Beverages & Tobacco         43   555967  12929.465116      43   51417
# Health Care                       75  1614707  21529.426667      75  106114
# ...

# %% [markdown]
# ## 08.115 Iterating through Groups

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = "Rank")
sectors = fortune.groupby(by = "Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
df = pd.DataFrame(columns = fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for sector, data in sectors:
    highest_revenue_company_in_group = data.nlargest(1, 'Revenue')
    df = df.append(highest_revenue_company_in_group)

# %%
df
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
cities = fortune.groupby('Location')
df = pd.DataFrame(columns = fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for city, data in cities:
    highest_revenue_in_city = data.nlargest(1, 'Revenue')
    df = df.append(highest_revenue_in_city)

# %%
df
# Out:
#                                   Company                        Sector  \
# 138                   Abbott Laboratories                   Health Care
# 169                Goodyear Tire & Rubber        Motor Vehicles & Parts
# 288              Air Products & Chemicals                     Chemicals
# 830                 Benchmark Electronics                    Technology
# 374                Casey’s General Stores                     Retailing
# 915                        Domino’s Pizza  Hotels, Resturants & Leisure
# 596                                Colfax                   Industrials
# 215                          Land O’Lakes     Food, Beverages & Tobacco
# 190                                   AES                        Energy
# 31                                    IBM                    Technology
# 28                             Home Depot                     Retailing
# 310                               Autoliv        Motor Vehicles & Parts
# ...
