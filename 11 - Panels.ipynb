# %% [markdown]
# ## 11.146 Intro to the Module + Fetch Dataset from Google Finance

# %%
import pandas as pd
from pandas_datareader import data

# %%
companies = ["MSFT", "GOOG", "AAPL", "YHOO", "AMZN"]

p = data.DataReader(name = companies, data_source = "google",
                start = "2010-01-01", end = "2016-12-31")

p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %% [markdown]
# ## 11.147 The Axes of a Panel Object

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
p.major_axis
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1761, freq=None)

# %%
p.minor_axis
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')

# %%
p.axes
# Out:
# [Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object'),
#  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                 '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                 '2010-01-14', '2010-01-15',
#                 ...
#                 '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                 '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                 '2016-12-29', '2016-12-30'],
#                dtype='datetime64[ns]', name='Date', length=1761, freq=None),
#  Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')]

# %% [markdown]
# ## 11.148 Panel Attributes

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p.axes
# Out:
# [Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object'),
#  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                 '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                 '2010-01-14', '2010-01-15',
#                 ...
#                 '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                 '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                 '2016-12-29', '2016-12-30'],
#                dtype='datetime64[ns]', name='Date', length=1761, freq=None),
#  Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')]

# %%
p.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
p.major_axis
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1761, freq=None)

# %%
p.minor_axis
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')

# %%
p.ndim
# Out:
# 3

# %%
p.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
p.shape
# Out:
# (5, 1761, 5)

# %%
p.size
# Out:
# 44025

# %%
5*1761*5
# Out:
# 44025

# %%
p.values
# Out:
# array([[[  3.04900000e+01,   1.36250000e+02,   3.13160000e+02,
#            3.06200000e+01,   1.69400000e+01],
#         [  3.06600000e+01,   1.33430000e+02,   3.13280000e+02,
#            3.08500000e+01,   1.72200000e+01],
#         [  3.06300000e+01,   1.34600000e+02,   3.12620000e+02,
#            3.08800000e+01,   1.71700000e+01],
#         ...,
#         [  1.17520000e+02,   7.76250000e+02,   7.93700000e+02,
#            6.34000000e+01,   3.91200000e+01],
#         [  1.16450000e+02,   7.72400000e+02,   7.83330000e+02,
#            6.28600000e+01,   3.87600000e+01],
#         [  1.16650000e+02,   7.66470000e+02,   7.82750000e+02,
#            6.29600000e+01,   3.87200000e+01]],
#
#        [[  3.06400000e+01,   1.36610000e+02,   3.14440000e+02,
#            3.11000000e+01,   1.72000000e+01],
#         [  3.08000000e+01,   1.35480000e+02,   3.13610000e+02,
#            3.11000000e+01,   1.72300000e+01],
#         [  3.07500000e+01,   1.34730000e+02,   3.12620000e+02,
# ...

# %% [markdown]
# ## 11.149 Use Bracket Notation to Extract a DataFrame (for Subsetting)

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
p['Volume'].head()
# Out:
#                    AAPL        AMZN  GOOG        MSFT        YHOO
# Date
# 2010-01-04  123432050.0   7600543.0   NaN  38414185.0  16588957.0
# 2010-01-05  150476004.0   8856456.0   NaN  49758862.0  11718126.0
# 2010-01-06  138039594.0   7180977.0   NaN  58182332.0  16421960.0
# 2010-01-07  119282324.0  11030124.0   NaN  50564285.0  31816301.0
# 2010-01-08  111969081.0   9833829.0   NaN  51201289.0  15471074.0

# %%
p.Volume
# Out:
#                    AAPL        AMZN       GOOG         MSFT        YHOO
# Date
# 2010-01-04  123432050.0   7600543.0        NaN   38414185.0  16588957.0
# 2010-01-05  150476004.0   8856456.0        NaN   49758862.0  11718126.0
# 2010-01-06  138039594.0   7180977.0        NaN   58182332.0  16421960.0
# 2010-01-07  119282324.0  11030124.0        NaN   50564285.0  31816301.0
# 2010-01-08  111969081.0   9833829.0        NaN   51201289.0  15471074.0
# 2010-01-11  115557365.0   8786668.0        NaN   68754648.0  16185267.0
# 2010-01-12  148614774.0   9098190.0        NaN   65913228.0  15674461.0
# 2010-01-13  151472335.0  10727856.0        NaN   51863463.0  16961731.0
# 2010-01-14  108288411.0   9788435.0        NaN   63244767.0  16717061.0
# 2010-01-15  148584065.0  15382763.0        NaN   79915648.0  18415868.0
# 2010-01-19  182501620.0   8900116.0        NaN   46582886.0  15182984.0
# 2010-01-20  153037892.0   9081533.0        NaN   54857712.0  14421141.0
# ...

# %% [markdown]
# ## 11.150 Extracting with the .loc[], .iloc[], and .ix[] Methods

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
p.loc['Low', '2014-04-08', 'GOOG']
# Out:
# 541.61000000000001

# %%
p.iloc[3, 200, 3]
# Out:
# 25.309999999999999

# %%
p.ix['High', 500, 'YHOO']
# Out:
# 16.050000000000001

# %% [markdown]
# ## 11.151 Convert Paanel to a MultiIndex DataFrame (and Vice Versa)

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
df = p.to_frame()

df.head()
# Out:
#                     Open    High     Low   Close       Volume
# Date       minor
# 2010-01-04 AAPL    30.49   30.64   30.34   30.57  123432050.0
#            AMZN   136.25  136.61  133.14  133.90    7600543.0
#            MSFT    30.62   31.10   30.59   30.95   38414185.0
#            YHOO    16.94   17.20   16.88   17.10   16588957.0
# 2010-01-05 AAPL    30.66   30.80   30.46   30.63  150476004.0

# %%
p2 = df.to_panel()
p2
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %% [markdown]
# ## 11.152 The .major_xs() Method

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p.items
p["Volume"]
# Out:
#                    AAPL        AMZN       GOOG         MSFT        YHOO
# Date
# 2010-01-04  123432050.0   7600543.0        NaN   38414185.0  16588957.0
# 2010-01-05  150476004.0   8856456.0        NaN   49758862.0  11718126.0
# 2010-01-06  138039594.0   7180977.0        NaN   58182332.0  16421960.0
# 2010-01-07  119282324.0  11030124.0        NaN   50564285.0  31816301.0
# 2010-01-08  111969081.0   9833829.0        NaN   51201289.0  15471074.0
# 2010-01-11  115557365.0   8786668.0        NaN   68754648.0  16185267.0
# 2010-01-12  148614774.0   9098190.0        NaN   65913228.0  15674461.0
# 2010-01-13  151472335.0  10727856.0        NaN   51863463.0  16961731.0
# 2010-01-14  108288411.0   9788435.0        NaN   63244767.0  16717061.0
# 2010-01-15  148584065.0  15382763.0        NaN   79915648.0  18415868.0
# 2010-01-19  182501620.0   8900116.0        NaN   46582886.0  15182984.0
# 2010-01-20  153037892.0   9081533.0        NaN   54857712.0  14421141.0
# ...

# %%
p.major_axis
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1761, freq=None)

# %%
p.major_xs('2013-12-20')
# Out:
#         Open    High     Low   Close       Volume
# AAPL   77.91   78.80   77.83   78.43  109103435.0
# AMZN  396.84  404.72  395.78  402.20    5038537.0
# GOOG  544.10  550.03  543.46  549.76          NaN
# MSFT   36.25   36.93   36.18   36.80   62650324.0
# YHOO   40.35   40.60   40.11   40.12   24640437.0

# %% [markdown]
# ## 11.153 The .minor_xs() Method

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p.minor_axis
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')

# %%
p.minor_xs('AAPL')
# Out:
#               Open    High     Low   Close       Volume
# Date
# 2010-01-04   30.49   30.64   30.34   30.57  123432050.0
# 2010-01-05   30.66   30.80   30.46   30.63  150476004.0
# 2010-01-06   30.63   30.75   30.11   30.14  138039594.0
# 2010-01-07   30.25   30.29   29.86   30.08  119282324.0
# 2010-01-08   30.04   30.29   29.87   30.28  111969081.0
# 2010-01-11   30.40   30.43   29.78   30.02  115557365.0
# 2010-01-12   29.88   29.97   29.49   29.67  148614774.0
# 2010-01-13   29.70   30.13   29.16   30.09  151472335.0
# 2010-01-14   30.02   30.07   29.86   29.92  108288411.0
# 2010-01-15   30.13   30.23   29.41   29.42  148584065.0
# 2010-01-19   29.76   30.74   29.61   30.72  182501620.0
# 2010-01-20   30.70   30.79   29.93   30.25  153037892.0
# 2010-01-21   30.30   30.47   29.60   29.72  152038565.0
# 2010-01-22   29.54   29.64   28.17   28.25  220441872.0
# 2010-01-25   28.93   29.24   28.60   29.01  266424802.0
# 2010-01-26   29.42   30.53   28.94   29.42  466777486.0
# ...

# %%
p.minor_xs('MSFT')
p.minor_xs("GOOG").head(3)
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2010-01-04  313.16  314.44  311.81  313.06     NaN
# 2010-01-05  313.28  313.61  310.46  311.68     NaN
# 2010-01-06  312.62  312.62  302.88  303.83     NaN

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p["Open"]
p.major_xs('2016-09-16')
p.minor_xs('YHOO').head(3)
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2010-01-04  16.94  17.20  16.88  17.10  16588957.0
# 2010-01-05  17.22  17.23  17.00  17.23  11718126.0
# 2010-01-06  17.17  17.30  17.07  17.17  16421960.0

# %% [markdown]
# ## 11.154 Transpose a Panel with the .transpose() Method

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p.axes
# Out:
# [Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object'),
#  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                 '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                 '2010-01-14', '2010-01-15',
#                 ...
#                 '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                 '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                 '2016-12-29', '2016-12-30'],
#                dtype='datetime64[ns]', name='Date', length=1761, freq=None),
#  Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')]

# %%
p2 = p.transpose(2, 1, 0)

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p2
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: AAPL to YHOO
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: Open to Volume

# %%
p2['GOOG']
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2010-01-04  313.16  314.44  311.81  313.06        NaN
# 2010-01-05  313.28  313.61  310.46  311.68        NaN
# 2010-01-06  312.62  312.62  302.88  303.83        NaN
# 2010-01-07  304.40  304.70  296.03  296.75        NaN
# 2010-01-08  295.70  301.32  294.26  300.71        NaN
# 2010-01-11  301.93  301.93  296.72  300.25        NaN
# 2010-01-12  298.74  298.78  293.71  294.94        NaN
# 2010-01-13  287.96  293.90  286.66  293.25        NaN
# 2010-01-14  291.66  296.80  291.11  294.63        NaN
# 2010-01-15  295.50  296.48  288.73  289.71        NaN
# 2010-01-19  290.45  294.91  287.86  293.52        NaN
# 2010-01-20  292.70  292.70  287.36  289.91        NaN
# 2010-01-21  291.43  293.12  285.84  291.20        NaN
# 2010-01-22  281.97  285.01  267.16  274.73        NaN
# 2010-01-25  273.02  274.66  267.49  269.73        NaN
# 2010-01-26  268.72  274.53  267.88  270.94        NaN
# ...

# %%
p2.major_xs('2010-01-04')
# Out:
#                 AAPL        AMZN    GOOG         MSFT         YHOO
# Open    3.049000e+01      136.25  313.16        30.62        16.94
# High    3.064000e+01      136.61  314.44        31.10        17.20
# Low     3.034000e+01      133.14  311.81        30.59        16.88
# Close   3.057000e+01      133.90  313.06        30.95        17.10
# Volume  1.234320e+08  7600543.00     NaN  38414185.00  16588957.00

# %%
p2.minor_xs('Volume')
# Out:
#                    AAPL        AMZN       GOOG         MSFT        YHOO
# Date
# 2010-01-04  123432050.0   7600543.0        NaN   38414185.0  16588957.0
# 2010-01-05  150476004.0   8856456.0        NaN   49758862.0  11718126.0
# 2010-01-06  138039594.0   7180977.0        NaN   58182332.0  16421960.0
# 2010-01-07  119282324.0  11030124.0        NaN   50564285.0  31816301.0
# 2010-01-08  111969081.0   9833829.0        NaN   51201289.0  15471074.0
# 2010-01-11  115557365.0   8786668.0        NaN   68754648.0  16185267.0
# 2010-01-12  148614774.0   9098190.0        NaN   65913228.0  15674461.0
# 2010-01-13  151472335.0  10727856.0        NaN   51863463.0  16961731.0
# 2010-01-14  108288411.0   9788435.0        NaN   63244767.0  16717061.0
# 2010-01-15  148584065.0  15382763.0        NaN   79915648.0  18415868.0
# 2010-01-19  182501620.0   8900116.0        NaN   46582886.0  15182984.0
# 2010-01-20  153037892.0   9081533.0        NaN   54857712.0  14421141.0
# ...

# %% [markdown]
# ## 11.155 The .swapaxes() Method

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1761 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
p2 = p.swapaxes('items', 'minor')

# %%
p2.axes
# Out:
# [Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object'),
#  DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                 '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                 '2010-01-14', '2010-01-15',
#                 ...
#                 '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                 '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                 '2016-12-29', '2016-12-30'],
#                dtype='datetime64[ns]', name='Date', length=1761, freq=None),
#  Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')]

# %%
p2["MSFT"]
p2.major_xs('2016-09-02')
p2.minor_xs('Close')
# Out:
#               AAPL    AMZN    GOOG   MSFT   YHOO
# Date
# 2010-01-04   30.57  133.90  313.06  30.95  17.10
# 2010-01-05   30.63  134.69  311.68  30.96  17.23
# 2010-01-06   30.14  132.25  303.83  30.77  17.17
# 2010-01-07   30.08  130.00  296.75  30.45  16.70
# 2010-01-08   30.28  133.52  300.71  30.66  16.70
# 2010-01-11   30.02  130.31  300.25  30.27  16.74
# 2010-01-12   29.67  127.35  294.94  30.07  16.68
# 2010-01-13   30.09  129.11  293.25  30.35  16.90
# 2010-01-14   29.92  127.35  294.63  30.96  17.12
# 2010-01-15   29.42  127.14  289.71  30.86  16.82
# 2010-01-19   30.72  127.61  293.52  31.10  16.75
# 2010-01-20   30.25  125.78  289.91  30.58  16.38
# 2010-01-21   29.72  126.62  291.20  30.01  16.20
# 2010-01-22   28.25  121.43  274.73  28.96  15.88
# 2010-01-25   29.01  120.31  269.73  29.32  15.86
# 2010-01-26   29.42  119.48  270.94  29.50  15.99
# 2010-01-27   29.70  122.75  270.78  29.67  15.98
# 2010-01-28   28.47  126.03  266.88  29.16  15.44
# ...
